# %%
import nltk
import string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = """
I usually like listening to music while studying. I believe that it helps me focus, while some people feel it can be distracting. The real question is: does music improve concentration, or does it reduce productivity?

Healthy habits are important to be followed by everyone. Eating nutritious food, exercising regularly, and getting enough sleep daily can improve us both physical and mental health. Doctors often say that: small lifestyle changes can make a big difference!
"""
print("Original Text:\n")
print(text)
# Out:
# Original Text:
#
#
# I usually like listening to music while studying. I believe that it helps me focus, while some people feel it can be distracting. The real question is: does music improve concentration, or does it reduce productivity?
#
# Healthy habits are important to be followed by everyone. Eating nutritious food, exercising regularly, and getting enough sleep daily can improve us both physical and mental health. Doctors often say that: small lifestyle changes can make a big difference!

# %%
text_remove_punctuation = text.translate(str.maketrans('', '', string.punctuation))
print(text_remove_punctuation)
# Out:
# I usually like listening to music while studying I believe that it helps me focus while some people feel it can be distracting The real question is does music improve concentration or does it reduce productivity
#
# Healthy habits are important to be followed by everyone Eating nutritious food exercising regularly and getting enough sleep daily can improve us both physical and mental health Doctors often say that small lifestyle changes can make a big difference

# %%
nltk.download('wordnet')
words = nltk.word_tokenize(text_remove_punctuation)
print(words)
# Out:
# ['I', 'usually', 'like', 'listening', 'to', 'music', 'while', 'studying', 'I', 'believe', 'that', 'it', 'helps', 'me', 'focus', 'while', 'some', 'people', 'feel', 'it', 'can', 'be', 'distracting', 'The', 'real', 'question', 'is', 'does', 'music', 'improve', 'concentration', 'or', 'does', 'it', 'reduce', 'productivity', 'Healthy', 'habits', 'are', 'important', 'to', 'be', 'followed', 'by', 'everyone', 'Eating', 'nutritious', 'food', 'exercising', 'regularly', 'and', 'getting', 'enough', 'sleep', 'daily', 'can', 'improve', 'us', 'both', 'physical', 'and', 'mental', 'health', 'Doctors', 'often', 'say', 'that', 'small', 'lifestyle', 'changes', 'can', 'make', 'a', 'big', 'difference']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print(stop_words)
# Out:
# {'ve', 'too', 'above', 'after', "she'll", "wouldn't", 'are', 'through', "it'd", 'such', 'herself', 'y', "we've", 'mightn', 'don', 'its', 'off', 'the', 'some', "doesn't", 'd', 'do', 'during', 'being', 'before', 'am', 'further', 'what', 'had', "i'll", "mustn't", 'at', 'those', 'himself', "they'll", 're', "we'd", 'against', "we're", 'you', 'their', 'should', "weren't", 'both', 'wouldn', 'm', 'them', 'me', "hadn't", "didn't", 'why', 'again', 'o', 'more', 'i', 'needn', 'all', "she'd", 'hadn', 'our', 'my', 'between', "i'm", 'her', 'on', 'now', 'theirs', 'an', "hasn't", 'were', 'been', 'for', 'once', "haven't", 'below', 'hasn', 'with', 'ours', 'weren', 'but', "he'll", 'under', 'is', 'by', "you'll", 'it', "wasn't", 'she', 'shouldn', 'your', 'does', 'him', 'if', 'shan', "you're", "we'll", 'hers', 'which', 'only', 'until', 'doesn', 'can', 'not', "shan't", 'he', "they'd", 'no', 'about', 'yourself', 'doing', 'nor', 'didn', "they're", "won't", 'that', 'did', 'they', 'yourselves', 'here', 'his', "
# ...

# %%
remaining_words = []
for word in words:
    if word.lower() not in stop_words:
        remaining_words.append(word)
print(remaining_words)
# Out:
# ['usually', 'like', 'listening', 'music', 'studying', 'believe', 'helps', 'focus', 'people', 'feel', 'distracting', 'real', 'question', 'music', 'improve', 'concentration', 'reduce', 'productivity', 'Healthy', 'habits', 'important', 'followed', 'everyone', 'Eating', 'nutritious', 'food', 'exercising', 'regularly', 'getting', 'enough', 'sleep', 'daily', 'improve', 'us', 'physical', 'mental', 'health', 'Doctors', 'often', 'say', 'small', 'lifestyle', 'changes', 'make', 'big', 'difference']

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stemmed_words = []
for word in remaining_words:
    stemmed_words.append(stemmer.stem(word))
print(stemmed_words)
# Out:
# ['usual', 'like', 'listen', 'music', 'studi', 'believ', 'help', 'focu', 'peopl', 'feel', 'distract', 'real', 'question', 'music', 'improv', 'concentr', 'reduc', 'product', 'healthi', 'habit', 'import', 'follow', 'everyon', 'eat', 'nutriti', 'food', 'exercis', 'regularli', 'get', 'enough', 'sleep', 'daili', 'improv', 'us', 'physic', 'mental', 'health', 'doctor', 'often', 'say', 'small', 'lifestyl', 'chang', 'make', 'big', 'differ']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_words = []
for word in remaining_words:
    lemmatized_words.append(lemmatizer.lemmatize(word))
print(lemmatized_words)
# Out:
# ['usually', 'like', 'listening', 'music', 'studying', 'believe', 'help', 'focus', 'people', 'feel', 'distracting', 'real', 'question', 'music', 'improve', 'concentration', 'reduce', 'productivity', 'Healthy', 'habit', 'important', 'followed', 'everyone', 'Eating', 'nutritious', 'food', 'exercising', 'regularly', 'getting', 'enough', 'sleep', 'daily', 'improve', 'u', 'physical', 'mental', 'health', 'Doctors', 'often', 'say', 'small', 'lifestyle', 'change', 'make', 'big', 'difference']
